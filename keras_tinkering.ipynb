# %%
def load_cifar_10():
    import pickle
    

    X_train, y_train = load_cifar_batches(['data_batch_%d' % i for i in (1, 2, 3, 4, 5)])
    X_test, y_test = load_cifar_batches('test_batch')

    return X_train, y_train, X_test, y_test

# %%
import pickle
import numpy as np

def load_cifar_batches(filenames):
        if isinstance(filenames, str):
            filenames = [filenames]
        images = []
        labels = []
        for fn in filenames:
            print(os.path.join('data', 'cifar-10', fn))
            with open(os.path.join('data', 'cifar-10', fn), 'rb') as f:
                data = pickle.load(f, encoding='bytes')
            images.append(np.asarray(data[b'data'], dtype='float32').reshape(-1, 3, 32, 32) / np.float32(255))
            labels.append(np.asarray(data[b'labels'], dtype='int32'))
        return np.concatenate(images), np.concatenate(labels)

# %%
X_train, y_train = load_cifar_batches(['data_batch_%d' % i for i in (1, 2, 3, 4, 5)])
X_test, y_test = load_cifar_batches('test_batch')
# Out:
# data/cifar-10/data_batch_1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-39367dd1623c> in <module>
# ----> 1 X_train, y_train = load_cifar_batches(['data_batch_%d' % i for i in (1, 2, 3, 4, 5)])
#       2 X_test, y_test = load_cifar_batches('test_batch')
#
# <ipython-input-13-3644672bb3f9> in load_cifar_batches(filenames)
#      11             with open(os.path.join('data', 'cifar-10', fn), 'rb') as f:
#      12                 data = cPickle.load(f, encoding='bytes')
# ---> 13             images.append(np.asarray(data['data'], dtype='float32').reshape(-1, 3, 32, 32) / np.float32(255))
#      14             labels.append(np.asarray(data['labels'], dtype='int32'))
#      15         return np.concatenate(images), np.concatenate(labels)
#
# KeyError: 'data'

# %%
import pickle

filenames = 'test_batch'
if isinstance(filenames, str):
    filenames = [filenames]
images = []
labels = []
print('testing!')
for fn in filenames:
    print(os.path.join('data', 'cifar-10', fn))
    with open(os.path.join('data', 'cifar-10', fn), 'rb') as f:
        data = pickle.load(f, encoding='bytes')
    print(data)
    images.append(np.asarray(data[b'data'], dtype='float32').reshape(-1, 3, 32, 32) / np.float32(255))
    labels.append(np.asarray(data[b'labels'], dtype='int32'))
# Out:
# _s_001405.png', b'ship_s_001648.png', b'pontoon_s_000880.png', b'plantation_walking_horse_s_000189.png', b'cat_s_002259.png', b'broodmare_s_000598.png', b'sea_boat_s_002209.png', b'tipper_truck_s_001758.png', b'tabby_s_000598.png', b'lipizzan_s_001826.png', b'aerial_ladder_truck_s_000675.png', b'gelding_s_001407.png', b'tugboat_s_001153.png', b'stallion_s_001017.png', b'truck_s_001834.png', b'lightship_s_000177.png', b'pekingese_s_001770.png', b'elk_s_001697.png', b'iceboat_s_000152.png', b'cat_s_000527.png', b'broodmare_s_000364.png', b'green_frog_s_001451.png', b'tabby_s_001734.png', b'packet_boat_s_001237.png', b'anthus_pratensis_s_000327.png', b'automobile_s_001549.png', b'fire_truck_s_001513.png', b'chihuahua_s_000907.png', b'dawn_horse_s_001571.png', b'felis_catus_s_000506.png', b'tipper_s_001316.png', b'dog_s_000626.png', b'mutt_s_002089.png', b'pilot_boat_s_000124.png', b'mare_s_000144.png', b'domestic_cat_s_001849.png', b'mutt_s_000111.png', b'tomcat_s_001045.png', b'chihuahua_s_001954.png', b'garbage_truck_s_002049.png', b'tennessee_walker_s_001442.png', b'pickerel_frog_s_000110.png', b'appaloosa_s_002239.png', b'tomcat_s_000913.png', b'green_frog_s_000224.png', b'capreolus_capreolus_s_000810.png', b'mouser_s_001271.png', b'tipper_truck_s_000574.png', b'deer_s_001171.png', b'honey_eater_s_000304.png', b'coupe_s_000815.png', b'fire_engine_s_001051.png', b'bufo_marinus_s_000363.png', b'attack_aircraft_s_001657.png', b'passerine_s_001770.png', b'toad_frog_s_001729.png', b'broodmare_s_000452.png', b'cervus_sika_s_000479.png', b'arabian_s_002399.png', b'camion_s_001292.png', b'jumbo_jet_s_001400.png', b'stallion_s_000399.png', b'american_elk_s_001633.png', b'alley_cat_s_002583.png', b'mutt_s_000787.png', b'tabby_cat_s_002286.png', b'coupe_s_000438.png', b'coupe_s_001388.png', b'emu_s_000397.png', b'green_frog_s_000898.png', b'pontoon_s_000051.png', b'dromaius_novaehollandiae_s_000360.png', b'bus_s_000146.png', b'lipizzan_s_001950.png', b'cargo_vessel_s_001797.png', b'puppy_s_000718.png', b'tipper_s_000359.png', b'texas_toad_s_000260.png', b'coupe_s_001760.png', b'ambulance_s_000365.png', b'blenheim_spaniel_s_000563.png', b'stealth_bomber_s_000060.png', b'bullfrog_s_000108.png', b'stealth_bomber_s_001670.png', b'dumper_s_001594.png', b'finch_s_000606.png', b'toad_frog_s_000914.png', b'chihuahua_s_000256.png', b'racing_boat_s_000559.png', b'articulated_lorry_s_000012.png', b'puppy_s_001340.png', b'toy_dog_s_000935.png', b'rana_clamitans_s_000699.png', b'bird_s_001161.png', b'fire_truck_s_001396.png', b'compact_s_001524.png', b'mongrel_s_002015.png', b'speedboat_s_000044.png', b'passenger_ship_s_000578.png', b'lippizaner_s_000001.png', b'taxicab_s_000486.png', b'gelding_s_001312.png', b'tabby_cat_s_001838.png', b'domestic_dog_s_000632.png', b'sambar_s_000248.png', b'ladder_truck_s_000259.png', b'arabian_s_002058.png', b'pekingese_s_001515.png', b'dromaius_novaehollandiae_s_000078.png', b'dump_truck_s_000023.png', b'tipper_s_001954.png', b'alces_alces_s_000718.png', b'lipizzan_s_002112.png', b'musk_deer_s_000091.png', b'motorcar_s_001544.png', b'tabby_cat_s_002618.png', b'sea_boat_s_001953.png', b'arabian_s_001990.png', b'tipper_truck_s_000020.png', b'stealth_fighter_s_001108.png', b'odocoileus_hemionus_s_000186.png', b'canis_familiaris_s_000381.png', b'walking_horse_s_000044.png', b'pekinese_s_001462.png', b'accentor_s_000131.png', b'ferry_s_000151.png', b'quarter_horse_s_001457.png', b'bufo_marinus_s_000928.png', b'transporter_s_000367.png', b'bufo_viridis_s_000477.png', b'trucking_rig_s_001159.png', b'felis_catus_s_000402.png', b'containership_s_000210.png', b'maltese_s_001431.png', b'true_frog_s_000294.png', b'pickerel_frog_s_000560.png', b'dump_truck_s_000539.png', b'maltese_s_001091.png', b'broodmare_s_000135.png', b'boat_s_000045.png', b'airliner_s_001698.png', b'pekinese_s_000769.png', b'dive_bomber_s_001222.png', b'lipizzan_s_000521.png', b'deer_s_000400.png', b'police_boat_s_000414.png', b'emu_s_000992.png', b'king_ ...

# %%
images
# Out:
# [array([[[[0.61960787, 0.62352943, 0.64705884, ..., 0.5372549 ,
#            0.49411765, 0.45490196],
#           [0.59607846, 0.5921569 , 0.62352943, ..., 0.53333336,
#            0.49019608, 0.46666667],
#           [0.5921569 , 0.5921569 , 0.61960787, ..., 0.54509807,
#            0.50980395, 0.47058824],
#           ...,
#           [0.26666668, 0.16470589, 0.12156863, ..., 0.14901961,
#            0.05098039, 0.15686275],
#           [0.23921569, 0.19215687, 0.13725491, ..., 0.10196079,
#            0.11372549, 0.07843138],
#           [0.21176471, 0.21960784, 0.1764706 , ..., 0.09411765,
#            0.13333334, 0.08235294]],
#
#          [[0.4392157 , 0.43529412, 0.45490196, ..., 0.37254903,
#            0.35686275, 0.33333334],
#           [0.4392157 , 0.43137255, 0.44705883, ..., 0.37254903,
#            0.35686275, 0.34509805],
#           [0.43137255, 0.42745098, 0.43529412, ..., 0.38431373,
#            0.37254903, 0.34901962],
#           ...,
#           [0.4862745 , 0.39215687, 0.34509805, ..., 0.38039216,
#            0.2509804 , 0.33333334],
#           [0.45490196, 0.4       , 0.33333334, ..., 0.32156864,
#            0.32156864, 0.2509804 ],
#           [0.41960785, 0.4117647 , 0.34901962, ..., 0.3019608 ,
#            0.32941177, 0.2627451 ]],
#
#          [[0.19215687, 0.18431373, 0.2       , ..., 0.14117648,
#            0.14117648, 0.12941177],
#           [0.2       , 0.15686275, 0.1764706 , ..., 0.12156863,
#            0.1254902 , 0.13333334],
#           [0.18431373, 0.12941177, 0.14117648, ..., 0.13333334,
#            0.13333334, 0.12941177],
#           ...,
#           [0.69411767, 0.5803922 , 0.5372549 , ..., 0.57254905,
#            0.42352942, 0.49803922],
#           [0.65882355, 0.5803922 , 0.5176471 , ..., 0.50980395,
#            0.49411765, 0.41960785],
#           [0.627451  , 0.58431375, 0.5176471 , ..., 0.4862745 ,
#            0.5058824 , 0.43137255]]],
#
#
#         [[[0.92156863, 0.90588236, 0.9098039 , ..., 0.9137255 ,
#            0.9137255 , 0.9098039 ],
#           [0.93333334, 0.92156863, 0.92156863, ..., 0.9254902 ,
#            0.9254902 , 0.92156863],
#           [0.92941177, 0.91764706, 0.91764706, ..., 0.92156863,
#            0.92156863, 0.91764706],
#           ...,
#           [0.34117648, 0.16862746, 0.07450981, ..., 0.6627451 ,
#            0.7137255 , 0.7372549 ],
#           [0.32156864, 0.18039216, 0.14117648, ..., 0.68235296,
#            0.7254902 , 0.73333335],
#           [0.33333334, 0.24313726, 0.22745098, ..., 0.65882355,
#            0.7058824 , 0.7294118 ]],
#
#          [[0.92156863, 0.90588236, 0.9098039 , ..., 0.9137255 ,
#            0.9137255 , 0.9098039 ],
#           [0.93333334, 0.92156863, 0.92156863, ..., 0.9254902 ,
#            0.9254902 , 0.92156863],
#           [0.92941177, 0.91764706, 0.91764706, ..., 0.92156863,
#            0.92156863, 0.91764706],
#           ...,
#           [0.3882353 , 0.2       , 0.09019608, ..., 0.72156864,
#            0.77254903, 0.7921569 ],
#           [0.3764706 , 0.22352941, 0.17254902, ..., 0.7411765 ,
#            0.78431374, 0.7921569 ],
#           [0.39607844, 0.29411766, 0.2627451 , ..., 0.7176471 ,
#            0.7647059 , 0.78431374]],
#
#          [[0.92156863, 0.90588236, 0.9098039 , ..., 0.9137255 ,
#            0.9137255 , 0.9098039 ],
#           [0.93333334, 0.92156863, 0.92156863, ..., 0.9254902 ,
#            0.9254902 , 0.92156863],
#           [0.92941177, 0.91764706, 0.91764706, ..., 0.92156863,
#            0.92156863, 0.91764706],
#           ...,
#           [0.34901962, 0.14509805, 0.04313726, ..., 0.7019608 ,
#            0.75686276, 0.7882353 ],
#           [0.32156864, 0.14117648, 0.08627451, ..., 0.7176471 ,
#            0.76862746, 0.78431374],
#           [0.3254902 , 0.1882353 , 0.14901961, ..., 0.69803923,
#            0.7490196 , 0.78039217]]],
#
#
#         [[[0.61960787, 0.61960787, 0.54509807, ..., 0.89411765,
#            0.92941177, 0.93333334],
#           [0.6666667 , 0.6745098 , 0.5921569 , ..., 0.9098039 ,
#            0.9647059 , 0.9647059 ],
#           [0.68235296, 0.6901961 , 0.6156863 , ..., 0.9019608 ,
#            0.98039216, 0.9607843 ],
#           ...,
#           [0.12156863, 0.11764706, 0.10196079, ..., 0.14509805,
#            0.03529412, 0.01568628],
#           [0.09019608, 0.10588235, 0.09803922, ..., 0.07450981,
#            0.01568628, 0.01960784],
#           [0.10980392, 0.11764706, 0.1254902 , ..., 0.01960784,
#            0.01568628, 0.02745098]],
#
#          [[0.74509805, 0.73333335, 0.6509804 , ..., 0.90588236,
#            0.9372549 , 0.94509804],
#           [0.78431374, 0.78039217, 0.6901961 , ..., 0.9098039 ,
#            0.9647059 , 0.96862745],
#           [0.7882353 , 0.78431374, 0.7019608 , ..., 0.8980392 ,
#            0.9764706 , 0.95686275],
#           ...,
#           [0.15686275, 0.15294118, 0.13725491, ..., 0.15686275,
#            0.05098039, 0.02745098],
#           [0.13333334, 0.14901961, 0.14117648, ..., 0.07843138,
#            0.02352941, 0.02745098],
#           [0.16078432, 0.16862746, 0.1764706 , ..., 0.02352941,
#            0.01960784, 0.03137255]],
#
#          [[0.87058824, 0.85490197, 0.7607843 , ..., 0.91764706,
#            0.9529412 , 0.9647059 ],
#           [0.8980392 , 0.8862745 , 0.7882353 , ..., 0.9254902 ,
#            0.98039216, 0.9843137 ],
#           [0.88235295, 0.87058824, 0.78039217, ..., 0.9098039 ,
#            0.9843137 , 0.96862745],
#           ...,
#           [0.1764706 , 0.17254902, 0.15686275, ..., 0.18039216,
#            0.05490196, 0.01960784],
#           [0.15294118, 0.16862746, 0.16078432, ..., 0.09411765,
#            0.01176471, 0.01176471],
#           [0.18431373, 0.19607843, 0.20392157, ..., 0.03137255,
#            0.01176471, 0.02745098]]],
#
#
#         ...,
#
#
#         [[[0.07843138, 0.07450981, 0.05882353, ..., 0.03921569,
#            0.04705882, 0.05098039],
#           [0.08235294, 0.07843138, 0.07058824, ..., 0.03921569,
#            0.03921569, 0.04705882],
#           [0.08235294, 0.08235294, 0.07843138, ..., 0.04705882,
#            0.04705882, 0.05098039],
#           ...,
#           [0.12941177, 0.13333334, 0.13333334, ..., 0.10980392,
#            0.11372549, 0.09019608],
#           [0.12941177, 0.13333334, 0.13333334, ..., 0.10588235,
#            0.10588235, 0.09803922],
#           [0.12156863, 0.1254902 , 0.12941177, ..., 0.09411765,
#            0.10196079, 0.09803922]],
#
#          [[0.05882353, 0.05490196, 0.05490196, ..., 0.03529412,
#            0.04313726, 0.04705882],
#           [0.0627451 , 0.0627451 , 0.06666667, ..., 0.03529412,
#            0.03529412, 0.04313726],
#           [0.0627451 , 0.06666667, 0.07058824, ..., 0.04313726,
#            0.04313726, 0.04705882],
#           ...,
#           [0.09803922, 0.10196079, 0.10196079, ..., 0.09803922,
#            0.09803922, 0.07843138],
#           [0.09803922, 0.10196079, 0.10196079, ..., 0.09411765,
#            0.09411765, 0.08627451],
#           [0.09019608, 0.09411765, 0.09803922, ..., 0.09019608,
#            0.09019608, 0.07843138]],
#
#          [[0.04705882, 0.04313726, 0.04313726, ..., 0.02745098,
#            0.03529412, 0.03921569],
#           [0.05098039, 0.05098039, 0.04705882, ..., 0.02745098,
#            0.02745098, 0.03529412],
#           [0.05098039, 0.04705882, 0.04313726, ..., 0.03529412,
#            0.03529412, 0.03921569],
#           ...,
#           [0.05098039, 0.05882353, 0.05882353, ..., 0.20392157,
#            0.22745098, 0.16470589],
#           [0.05490196, 0.05882353, 0.05882353, ..., 0.20392157,
#            0.21960784, 0.18431373],
#           [0.04705882, 0.05098039, 0.05490196, ..., 0.19607843,
#            0.20784314, 0.18431373]]],
#
#
#         [[[0.09803922, 0.05882353, 0.09019608, ..., 0.23921569,
#            0.36078432, 0.29411766],
#           [0.04705882, 0.07843138, 0.09411765, ..., 0.4509804 ,
#            0.58431375, 0.40784314],
#           [0.04705882, 0.05882353, 0.13333334, ..., 0.6039216 ,
#            0.6156863 , 0.45490196],
#           ...,
#           [0.39215687, 0.40392157, 0.40784314, ..., 0.38039216,
#            0.38431373, 0.35686275],
#           [0.40392157, 0.40784314, 0.41960785, ..., 0.39607844,
#            0.3882353 , 0.36078432],
#           [0.37254903, 0.37254903, 0.39607844, ..., 0.3647059 ,
#            0.37254903, 0.36078432]],
#
#          [[0.15686275, 0.14117648, 0.16078432, ..., 0.32156864,
#            0.44313726, 0.34901962],
#           [0.09803922, 0.14509805, 0.14117648, ..., 0.5254902 ,
#            0.65882355, 0.45882353],
#           [0.09803922, 0.11372549, 0.15686275, ..., 0.6745098 ,
#            0.6862745 , 0.5058824 ],
#           ...,
#           [0.5058824 , 0.5176471 , 0.5254902 , ..., 0.5019608 ,
#            0.49411765, 0.4745098 ],
#           [0.5176471 , 0.5137255 , 0.5294118 , ..., 0.5176471 ,
#            0.49803922, 0.4745098 ],
#           [0.49411765, 0.48235294, 0.5019608 , ..., 0.4862745 ,
#            0.48235294, 0.47058824]],
#
#          [[0.04705882, 0.01176471, 0.07058824, ..., 0.30588236,
#            0.4392157 , 0.36078432],
#           [0.02352941, 0.02745098, 0.05882353, ..., 0.5411765 ,
#            0.69411767, 0.5137255 ],
#           [0.04313726, 0.02352941, 0.09411765, ..., 0.7137255 ,
#            0.7529412 , 0.5921569 ],
#           ...,
#           [0.31764707, 0.32941177, 0.3372549 , ..., 0.32941177,
#            0.32941177, 0.30980393],
#           [0.3254902 , 0.3254902 , 0.34117648, ..., 0.34117648,
#            0.32941177, 0.30980393],
#           [0.30588236, 0.29803923, 0.31764707, ..., 0.3137255 ,
#            0.31764707, 0.3137255 ]]],
#
#
#         [[[0.28627452, 0.38431373, 0.3882353 , ..., 0.5294118 ,
#            0.5294118 , 0.79607844],
#           [0.27058825, 0.32941177, 0.26666668, ..., 0.33333334,
#            0.2784314 , 0.47058824],
#           [0.27058825, 0.3529412 , 0.24313726, ..., 0.2901961 ,
#            0.20784314, 0.24313726],
#           ...,
#           [0.48235294, 0.5176471 , 0.5058824 , ..., 0.42352942,
#            0.24313726, 0.10588235],
#           [0.4509804 , 0.48235294, 0.5058824 , ..., 0.4509804 ,
#            0.25882354, 0.10588235],
#           [0.45490196, 0.4745098 , 0.5058824 , ..., 0.45490196,
#            0.26666668, 0.10588235]],
#
#          [[0.30588236, 0.40392157, 0.41568628, ..., 0.5882353 ,
#            0.58431375, 0.84313726],
#           [0.28627452, 0.34901962, 0.29411766, ..., 0.37254903,
#            0.32156864, 0.52156866],
#           [0.28627452, 0.37254903, 0.2784314 , ..., 0.31764707,
#            0.24313726, 0.2901961 ],
#           ...,
#           [0.5019608 , 0.5176471 , 0.5019608 , ..., 0.41960785,
#            0.23529412, 0.10588235],
#           [0.4745098 , 0.4862745 , 0.49411765, ..., 0.45490196,
#            0.25490198, 0.10588235],
#           [0.47058824, 0.47843137, 0.5019608 , ..., 0.4509804 ,
#            0.25490198, 0.10196079]],
#
#          [[0.29411766, 0.44313726, 0.44705883, ..., 0.59607846,
#            0.6039216 , 0.8745098 ],
#           [0.27450982, 0.38039216, 0.31764707, ..., 0.34901962,
#            0.3137255 , 0.5294118 ],
#           [0.27450982, 0.39215687, 0.2901961 , ..., 0.27450982,
#            0.21176471, 0.27058825],
#           ...,
#           [0.3764706 , 0.4       , 0.39215687, ..., 0.34509805,
#            0.21568628, 0.10980392],
#           [0.35686275, 0.37254903, 0.3882353 , ..., 0.36862746,
#            0.23137255, 0.10588235],
#           [0.3529412 , 0.36862746, 0.39607844, ..., 0.36862746,
#            0.22745098, 0.10196079]]]], dtype=float32)]

# %%
data[b'data']
# Out:
# array([[158, 159, 165, ..., 124, 129, 110],
#        [235, 231, 232, ..., 178, 191, 199],
#        [158, 158, 139, ...,   8,   3,   7],
#        ...,
#        [ 20,  19,  15, ...,  50,  53,  47],
#        [ 25,  15,  23, ...,  80,  81,  80],
#        [ 73,  98,  99, ...,  94,  58,  26]], dtype=uint8)
